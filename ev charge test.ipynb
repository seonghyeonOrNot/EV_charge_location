# %%
import numpy as np
import pandas as pd

import folium
from folium import Marker
from folium.plugins import MarkerCluster

# %%
ev_stations_df = pd.read_csv('/content/ev_stations_v1.csv')
ev_stations_df.head()
# Out:
# <ipython-input-10-d52259811c8b>:1: DtypeWarning: Columns (6,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   ev_stations_df = pd.read_csv('/content/ev_stations_v1.csv')
#   Fuel Type Code                     Station Name         Street Address  \
# 0           ELEC         LADWP - Truesdale Center     11797 Truesdale St
# 1           ELEC  LADWP - West LA District Office  1394 S Sepulveda Blvd
# 2           ELEC    Los Angeles Convention Center     1201 S Figueroa St
# 3           ELEC    LADWP - John Ferraro Building          111 N Hope St
# 4           ELEC       LADWP - Haynes Power Plant          6801 E 2nd St
#
#     Intersection Directions         City State    ZIP  Plus4 Station Phone  \
# 0                       NaN   Sun Valley    CA  91352    NaN           NaN
# 1                       NaN  Los Angeles    CA  90024    NaN           NaN
# 2  West hall and South hall  Los Angeles    CA  90015    NaN  213-741-1151
# 3               Across Hope  Los Angeles    CA  90012    NaN           NaN
# 4                       NaN   Long Beach    CA  90803    NaN           NaN
#
#   Status Code  ... EV Pricing (French) LPG Nozzle Types Hydrogen Pressures  \
# 0           E  ...                 NaN              NaN                NaN
# 1           E  ...                 NaN              NaN                NaN
# 2           E  ...                 NaN              NaN                NaN
# 3           E  ...                 NaN              NaN                NaN
# 4           E  ...                 NaN              NaN                NaN
#
#   Hydrogen Standards  CNG Fill Type Code  CNG PSI  CNG Vehicle Class  \
# 0                NaN                 NaN      NaN                NaN
# 1                NaN                 NaN      NaN                NaN
# 2                NaN                 NaN      NaN                NaN
# 3                NaN                 NaN      NaN                NaN
# 4                NaN                 NaN      NaN                NaN
#
#    LNG Vehicle Class  EV On-Site Renewable Source  Restricted Access
# 0                NaN                          NaN                NaN
# 1                NaN                          NaN                NaN
# 2                NaN                          NaN                NaN
# 3                NaN                          NaN                NaN
# 4                NaN                          NaN                NaN
#
# [5 rows x 65 columns]

# %%
ev_stations_df.columns
# Out:
# Index(['Fuel Type Code', 'Station Name', 'Street Address',
#        'Intersection Directions', 'City', 'State', 'ZIP', 'Plus4',
#        'Station Phone', 'Status Code', 'Expected Date',
#        'Groups With Access Code', 'Access Days Time', 'Cards Accepted',
#        'BD Blends', 'NG Fill Type Code', 'NG PSI', 'EV Level1 EVSE Num',
#        'EV Level2 EVSE Num', 'EV DC Fast Count', 'EV Other Info', 'EV Network',
#        'EV Network Web', 'Geocode Status', 'Latitude', 'Longitude',
#        'Date Last Confirmed', 'ID', 'Updated At', 'Owner Type Code',
#        'Federal Agency ID', 'Federal Agency Name', 'Open Date',
#        'Hydrogen Status Link', 'NG Vehicle Class', 'LPG Primary',
#        'E85 Blender Pump', 'EV Connector Types', 'Country',
#        'Intersection Directions (French)', 'Access Days Time (French)',
#        'BD Blends (French)', 'Groups With Access Code (French)',
#        'Hydrogen Is Retail', 'Access Code', 'Access Detail Code',
#        'Federal Agency Code', 'Facility Type', 'CNG Dispenser Num',
#        'CNG On-Site Renewable Source', 'CNG Total Compression Capacity',
#        'CNG Storage Capacity', 'LNG On-Site Renewable Source',
#        'E85 Other Ethanol Blends', 'EV Pricing', 'EV Pricing (French)',
#        'LPG Nozzle Types', 'Hydrogen Pressures', 'Hydrogen Standards',
#        'CNG Fill Type Code', 'CNG PSI', 'CNG Vehicle Class',
#        'LNG Vehicle Class', 'EV On-Site Renewable Source',
#        'Restricted Access'],
#       dtype='object')

# %%
# 데이터프레임에서 'Latitude'와 'Longitude' 열이 모두 null이 아닌 행만 선택
locations_df = ev_stations_df[ev_stations_df['Latitude'].notnull() & ev_stations_df['Longitude'].notnull()]

# 'State' 열이 'NC'이고 'City' 열이 'Charlotte'인 행만 선택 -> 노스캐롤라이나 주(Charlotte)의 충전소 위치 데이터만을 추출
Charlotte_NC_locations_df = locations_df[(locations_df['State'] == 'NC') & (locations_df['City'] == 'Charlotte')]
Charlotte_NC_locations_df.head()
# Out:
#      Fuel Type Code                  Station Name            Street Address  \
# 640            ELEC    CLT AIRPORT BV2 BASEMENT 1       5601 Wilkinson Blvd
# 730            ELEC      The Green Parking Garage            435 S Tryon St
# 1188           ELEC  CHARLOTTE, NC CMGC STATION 4         232 S Davidson St
# 1189           ELEC   CHARLOTTE, NC MALLARD CK 02         1712 J N Pease Pl
# 1627           ELEC         East Charlotte Nissan  6901 E Independence Blvd
#
#                           Intersection Directions       City State    ZIP  \
# 640                                           NaN  Charlotte    NC  28208
# 730   At S Tryon St and Levine Avenue of the Arts  Charlotte    NC  28202
# 1188                                          NaN  Charlotte    NC  28202
# 1189                                          NaN  Charlotte    NC  28262
# 1627                                          NaN  Charlotte    NC  28227
#
#       Plus4 Station Phone Status Code  ... EV Pricing (French)  \
# 640     NaN  888-758-4389           E  ...                 NaN
# 730     NaN  604-338-3232           E  ...                 NaN
# 1188    NaN  888-758-4389           E  ...                 NaN
# 1189    NaN  888-758-4389           E  ...                 NaN
# 1627    NaN  704-535-4012           E  ...                 NaN
#
#      LPG Nozzle Types Hydrogen Pressures Hydrogen Standards  \
# 640               NaN                NaN                NaN
# 730               NaN                NaN                NaN
# 1188              NaN                NaN                NaN
# 1189              NaN                NaN                NaN
# 1627              NaN                NaN                NaN
#
#       CNG Fill Type Code  CNG PSI  CNG Vehicle Class  LNG Vehicle Class  \
# 640                  NaN      NaN                NaN                NaN
# 730                  NaN      NaN                NaN                NaN
# 1188                 NaN      NaN                NaN                NaN
# 1189                 NaN      NaN                NaN                NaN
# 1627                 NaN      NaN                NaN                NaN
#
#       EV On-Site Renewable Source  Restricted Access
# 640                           NaN                NaN
# 730                           NaN                NaN
# 1188                          NaN                NaN
# 1189                          NaN                NaN
# 1627                          NaN                NaN
#
# [5 rows x 65 columns]

# %%
# 지도 만들기
charlotte_map = folium.Map(location=[35.227,-80.843], tiles='openstreetmap', zoom_start=11)

# 지도에 포인트 추가하기
for idx, row in Charlotte_NC_locations_df.iterrows():
    Marker(location=[row['Latitude'], row['Longitude']],
           popup=row['Street Address']).add_to(charlotte_map)

# 지도 노출
charlotte_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_007dbb1ca73529055e47d7324b9616be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_007dbb1ca73529055e47d7324b9616be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_007dbb1ca73529055e47d7324b9616be = L.map(
#                 &quot;map_007dbb1ca73529055e47d7324b9616be&quot;,
#                 {
#                     center: [35.227, -80.843],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff5a4a65f07bfdaac9ef50a7be980023 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_007dbb1ca73529055e47d7324b9616be);
#
#
#             var marker_577bfe7f964c27624cb4bcbdd228b385 = L.marker(
#                 [35.233542, -80.936932],
#                 {}
#             ).addTo(map_007dbb1ca73529055e47d7324b9616be);
#
#
#         var popup_6930c7473f240960a1ad84f4aa46fdc0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c2b8680424b0c545c65b2e13d9294861 = $(`&lt;div id=&quot;html_c2b8680424b0c545c65b2e13d9294861&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5601 Wilkinson Blvd&lt;/div&gt;`)[0];
#                 popup_6930c7473f240960a1ad84f4aa46fdc0.setContent(html_c2b8680424b0c545c65b2e13d9294861);
#
#
#
#         marker_577bfe7f964c27624cb4bcbdd228b385.bindPopup(popup_6930c7473f240960a1ad84f4aa46fdc0)
#         ;
#
#
#
#
#             var marker_552d048afb568cbff6ceac48cfdaad70 = L.marker(
#                 [35.223874, -80.846273],
#                 {}
#             ).addTo(map_007dbb1ca73529055e47d7324b9616be);
#
#
#         var popup_3c1e42d9caa0c96a31cedc7ee43fa219 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_585456f5713ae10a96544287ef8001ed = $(`&lt;div id=&quot;html_585456f5713ae10a96544287ef8001ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;435 S Tryon St&lt;/div&gt;`)[0];
#                 popup_3c1e42d9caa0c96a31cedc7ee43fa219.setContent(html_585456f5713ae10a96544287ef8001ed);
#
#
#
#         marker_552d048afb568cbff6ceac48cfdaad70.bindPopup(popup_3c1e42d9caa0c96a31cedc7ee43fa219)
#         ;
#
#
#
#
#             var marker_47e2618708995529020bac769fe871f6 = L.marker(
#                 [35.221981, -80.839984],
#                 {}
#             ).addTo(map_007dbb1ca73529055e47d7324b9616be);
#
#
#         var popup_161bf431d9711f9ef404a30e3063b73a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_900d41839a566c25c6c004f34229d7e3 = $(`&lt;div id=&quot;html_900d41839a566c25c6c004f34229d7e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;232 S Davidson St&lt;/div&gt;`)[0];
#                 popup_161bf431d9711f9ef404a30e3063b73a.setContent(html_900d41839a566c25c6c004f34229d7e3);
#
#
#
#         marker_47e2618708995529020bac769fe871f6.bindPopup(popup_161bf431d9711f9ef404a30e3063b73a)
#         ;
#
#
#
#
#             var marker_c9c074b99971cf7c0dbde3eecc5c0d9f = L.marker(
#                 [35.323848, -80.773027],
#                 {}
#             ).addTo(map_007dbb1ca73529055e47d7324b9616be);
#
#
#         var popup_7a0f7a6dc3c9111b88c5f7370537c1c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9e30b9b63adebeb37553891fb2011dcd = $(`&lt;div id=&quot;html_9e30b9b63adebeb37553891fb2011dcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1712 J N Pease Pl&lt;/div&gt;`)[0];
#                 popup_7a0f7a6dc3c9111b88c5f7370537c1c4.setContent(html_9e30b9b63adebeb37553891fb2011dcd);
#
#
#
#         marker_c9c074b99971cf7c0dbde3eecc5c0d9f.bindPopup(popup_7a0f7a6dc3c9111b88c5f7370537c1c4)
#         ;
#
#
#
#
#             var marker_44ec0f739cd7ffc0e83a48c2480eb224 = L.marker(
#                 [35.167774, -80.742259],
#                 {}
#             ).addTo(map_007dbb1ca73529055e47d7324b9616be);
#
#
#         var popup_1932de25dd236d578189db60f59f39cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b6080c05934fb89f6ead38db5d8e1ba5 = $(`&lt;div id=&quot;html_b6080c05934fb89f6ead38db5d8e1ba5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6901 E Independence Blvd&lt;/div&gt;`)[0];
#                 popup_1932de25dd236d578189db60f59f39cd.setContent(html_b6080c05934fb89f6ead38db5d8e1ba5);
#
#
#
#         marker_44ec0f739cd7ffc0e83a48c2480eb224.bindPopup(popup_1932de25dd236d578189db60f59f39cd)
#         ;
#
#
#
#
#             var marker_84cecd9589735d4c950a4ebe5d1ce1e3 = L.marker(
#                 [35.167774, -8

# %%
NC_locations_df = locations_df[(locations_df['State'] == 'NC')]
NC_locations_df.head()
# Out:
#     Fuel Type Code                          Station Name      Street Address  \
# 240           ELEC  City of Raleigh - Municipal Building    285 W Hargett St
# 241           ELEC            City of Raleigh - Downtown   215 W Cabarrus St
# 521           ELEC               Modern Nissan - Concord  967 Concord Pkwy S
# 522           ELEC                  Fred Anderson Nissan     4559 Raeford Rd
# 523           ELEC          Vann Yorks High Point Nissan      1810 S Main St
#
#             Intersection Directions          City State    ZIP  Plus4  \
# 240  Street pay parking at the curb       Raleigh    NC  27601    NaN
# 241      Street parking at the curb       Raleigh    NC  27601    NaN
# 521                             NaN       Concord    NC  28027    NaN
# 522                             NaN  Fayetteville    NC  28304    NaN
# 523                             NaN    High Point    NC  27260    NaN
#
#     Station Phone Status Code  ... EV Pricing (French) LPG Nozzle Types  \
# 240  919-996-3030           E  ...                 NaN              NaN
# 241  919-996-3030           E  ...                 NaN              NaN
# 521  704-788-2110           E  ...                 NaN              NaN
# 522  910-758-2338           E  ...                 NaN              NaN
# 523  336-884-4122           E  ...                 NaN              NaN
#
#     Hydrogen Pressures Hydrogen Standards  CNG Fill Type Code  CNG PSI  \
# 240                NaN                NaN                 NaN      NaN
# 241                NaN                NaN                 NaN      NaN
# 521                NaN                NaN                 NaN      NaN
# 522                NaN                NaN                 NaN      NaN
# 523                NaN                NaN                 NaN      NaN
#
#      CNG Vehicle Class  LNG Vehicle Class  EV On-Site Renewable Source  \
# 240                NaN                NaN                          NaN
# 241                NaN                NaN                          NaN
# 521                NaN                NaN                          NaN
# 522                NaN                NaN                          NaN
# 523                NaN                NaN                          NaN
#
#      Restricted Access
# 240                NaN
# 241                NaN
# 521                NaN
# 522                NaN
# 523                NaN
#
# [5 rows x 65 columns]

# %%
# Create a map centered on North Carolina
nc_map = folium.Map(location=[35.5908438,-79.7628341], tiles='openstreetmap', zoom_start=7)

# Add points to a marker cluster
mc = MarkerCluster()
for idx, row in NC_locations_df.iterrows():
    mc.add_child(Marker(location=[row['Latitude'], row['Longitude']],
                        popup=row['Street Address']))

# add the marker cluster to the map
nc_map.add_child(mc)

# Display the map
nc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c55d9a57ec0edb1213b3a903a0ef0155 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c55d9a57ec0edb1213b3a903a0ef0155&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c55d9a57ec0edb1213b3a903a0ef0155 = L.map(
#                 &quot;map_c55d9a57ec0edb1213b3a903a0ef0155&quot;,
#                 {
#                     center: [35.5908438, -79.7628341],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bcbf5c1d77ec3c2189219050f37915a1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c55d9a57ec0edb1213b3a903a0ef0155);
#
#
#             var marker_cluster_d1fb01860744bd2e1a435b87e12d1e96 = L.markerClusterGroup(
#                 {}
#             );
#             map_c55d9a57ec0edb1213b3a903a0ef0155.addLayer(marker_cluster_d1fb01860744bd2e1a435b87e12d1e96);
#
#
#             var marker_0509087d23bf1f7d8ccf29fa48618673 = L.marker(
#                 [35.778416, -78.64347],
#                 {}
#             ).addTo(marker_cluster_d1fb01860744bd2e1a435b87e12d1e96);
#
#
#         var popup_f30a96893269094e039cdb2b8e4bca6d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ff2c42f3d3d88c9bdebaf1e6af47288 = $(`&lt;div id=&quot;html_1ff2c42f3d3d88c9bdebaf1e6af47288&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;285 W Hargett St&lt;/div&gt;`)[0];
#                 popup_f30a96893269094e039cdb2b8e4bca6d.setContent(html_1ff2c42f3d3d88c9bdebaf1e6af47288);
#
#
#
#         marker_0509087d23bf1f7d8ccf29fa48618673.bindPopup(popup_f30a96893269094e039cdb2b8e4bca6d)
#         ;
#
#
#
#
#             var marker_a9d146f3386adf6a8662d6f90a2f3a0b = L.marker(
#                 [35.77435, -78.642287],
#                 {}
#             ).addTo(marker_cluster_d1fb01860744bd2e1a435b87e12d1e96);
#
#
#         var popup_811e0ecf478b74ccae6910343997faf1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b35cf431f55486fe68e935b4713aaef2 = $(`&lt;div id=&quot;html_b35cf431f55486fe68e935b4713aaef2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;215 W Cabarrus St&lt;/div&gt;`)[0];
#                 popup_811e0ecf478b74ccae6910343997faf1.setContent(html_b35cf431f55486fe68e935b4713aaef2);
#
#
#
#         marker_a9d146f3386adf6a8662d6f90a2f3a0b.bindPopup(popup_811e0ecf478b74ccae6910343997faf1)
#         ;
#
#
#
#
#             var marker_ca02ab280607c1dc8eba71c7ab02d83e = L.marker(
#                 [35.392063, -80.622777],
#                 {}
#             ).addTo(marker_cluster_d1fb01860744bd2e1a435b87e12d1e96);
#
#
#         var popup_d579707ae006059a62aad2e36c6bbfc1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9332061e566a372c930be385a15913a6 = $(`&lt;div id=&quot;html_9332061e566a372c930be385a15913a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;967 Concord Pkwy S&lt;/div&gt;`)[0];
#                 popup_d579707ae006059a62aad2e36c6bbfc1.setContent(html_9332061e566a372c930be385a15913a6);
#
#
#
#         marker_ca02ab280607c1dc8eba71c7ab02d83e.bindPopup(popup_d579707ae006059a62aad2e36c6bbfc1)
#         ;
#
#
#
#
#             var marker_a050a17314081e310ed92ae3f5645b0f = L.marker(
#                 [35.042419, -78.956747],
#                 {}
#             ).addTo(marker_cluster_d1fb01860744bd2e1a435b87e12d1e96);
#
#
#         var popup_abb6ad79f6c4880af403af6e036cbb2d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30cf4107eb34e3df64705e4d4c53a52e = $(`&lt;div id=&quot;html_30cf4107eb34e3df64705e4d4c53a52e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4559 Raeford Rd&lt;/div&gt;`)[0];
#                 popup_abb6ad79f6c4880af403af6e036cbb2d.setContent(html_30cf4107eb34e3df64705e4d4c53a52e);
#
#
#
#         marker_a050a17314081e310ed92ae3f5645b0f.bindPopup(popup_abb6ad79f6c4880af403af6e036cbb2d)
#         ;
#
#
#
#
#             var marker_1315d2af2d0343f705b65e2cd56c834c = L.marker(
#                 [35.937981, -79.996012],
#                 {}
#             ).addTo(marker_cluster_d1f

# %%
# 한국기준 테스트

# 지도 객체 생성
map = folium.Map(location=[37.5665, 126.9780], zoom_start=13)

# 마커 추가
folium.Marker(location=[37.5665, 126.9780], popup='서울특별시청').add_to(map)
folium.Marker(location=[37.5645, 126.9750], popup='덕수궁').add_to(map)

# 지도 출력
map.save('map.html')
